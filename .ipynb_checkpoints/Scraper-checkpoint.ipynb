# %%
pip install requests beautifulsoup4 pandas time
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement time (from versions: none)
# ERROR: No matching distribution found for time
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

from bs4 import BeautifulSoup
import pandas as pd
import time

# URL of the website to scrape
url = "https://wits.worldbank.org/wits/wits/witshelp/content/codes/country_codes.htm"

# Send an HTTP GET request to the website
response = requests.get(url)

# %%
# Parse the HTML code using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <html madcap:tocpath="Annexes" xmlns:madcap="http://www.madcapsoftware.com/Schemas/MadCap.xsd">
# <head><title>Country Codes</title>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="target-densitydpi=device-dpi, initial-scale=1.0, user-scalable=no" name="viewport"/><link href="https://wits.worldbank.org/WITS/WITS/WITSHELP/css/Data_Retrieval.css" rel="stylesheet"/>
# <link href="https://wits.worldbank.org/WITS/WITS/WITSHELP/css/MadCap.css" rel="stylesheet"/>
# <link href="https://wits.worldbank.org/WITS/WITS/WITSHELP/css/Styles.css" rel="stylesheet"/>
# <!---Styles for left navigation -->
# <link href="https://wits.worldbank.org/WITS/WITS/WITSHELP/css/jqx.base.css" rel="stylesheet" type="text/css"/>
# <link href="https://wits.worldbank.org/WITS/WITS/WITSHELP/css/help.css" media="screen" rel="stylesheet"/>
# <!--Scripts for left navigation -->
# ...

# %%
ignore_list = ['WH1','WN','WTH','WTNR','WTNR']
country_names = []
country_codes = []
iso3 = []
i = 0 
for paragraph in soup.find_all('p'): 
    try:
        name_class = paragraph.get('class')[0]
    except TypeError:
        print("End of the list")
    if name_class in ignore_list: 
        continue
    elif name_class == 'WTN': 
        country_names.append(paragraph.get_text())
    elif name_class == 'WTNC':
        if i == 0: 
            country_codes.append(paragraph.get_text())
            i = 1
        else: 
            iso3.append(paragraph.get_text())
            i = 0 
    #print(name_class)
    #print(paragraph)
# Out:
# End of the list
# End of the list

# %%
print(country_names)
# Out:
# ['Afghanistan\r\n                    ', 'Albania\r\n                    ', 'Algeria\r\n                    ', 'American Samoa\r\n                    ', 'Andorra ', 'Angola\r\n                    ', 'Anguila\r\n                    ', 'Antigua and Barbuda\r\n                    ', 'Argentina\r\n                    ', 'Armenia ', 'Aruba\r\n                    ', 'Australia\r\n                    ', 'Austria\r\n                    ', 'Azerbaijan ', 'Bahamas, The\r\n                    ', 'Bahrain ', 'Bangladesh ', 'Barbados ', 'Belarus ', 'Belgium ', 'Belgium-Luxembourg\r\n                    ', 'Belize ', 'Benin\r\n                    ', 'Bermuda\r\n                    ', 'Bhutan\r\n                    ', 'Bolivia\r\n                    ', 'Bosnia and Herzegovina ', 'Botswana ', 'Br. Antr. Terr\r\n                    ', 'Brazil ', 'British Indian Ocean Ter.\r\n                    ', 'British Virgin Islands ', 'Brunei ', 'Bulgaria\r\n                    ', 'Burkina Faso\r\n              
# ...
